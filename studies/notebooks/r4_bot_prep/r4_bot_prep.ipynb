# %% [markdown]
# # R4 bot prep — stop-loss grid and late-entry curve (2026-09-06)
#
# Pre-registered in [README.md](README.md); verdicts in [findings.md](findings.md). The cell below re-runs the sweep read-only against `prod.db` (≈2 min) and prints both tables plus the rule-based decision.

# %%
# %run sl_sweep.py

# %% [markdown]
# ## Results on disk
#
# The same numbers as CSV, for other notebooks.

# %%
import pandas as pd
pd.set_option('display.width', 200)
display(pd.read_csv('results/sl_sweep.csv').round(1))
display(pd.read_csv('results/late_entry.csv').round(1))
